# %% [markdown]
# <a href="https://colab.research.google.com/github/SilviteXSalute/yolov8/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.6/515.6 kB 31.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 21.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Colab Notebooks/IMG_20230119_170727.jpg"
image = cv2.imread(path)
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()

# %%
model = YOLO("yolov8x.pt")
results = model(new_image)
cv2.imwrite("yolov8x_IMG_20230119_170727(AI).jpg", results[0].plot())
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 299MB/s]
#
# 0: 480x640 2 persons, 3 cars, 76.0ms
# Speed: 0.5ms preprocess, 76.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# True
